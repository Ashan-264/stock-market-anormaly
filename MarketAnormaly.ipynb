# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('FinancialMarketData.xlsx - EWS.csv')

# %%
df
# Out:
#       Y       Data  XAU BGNL  ECSURPUS    BDIY       CRY      DXY     JPY  \
# 0     0  1/11/2000    283.25     0.077  1388.0  157.2600  100.560  105.86
# 1     0  1/18/2000    287.65     0.043  1405.0  165.0100  101.860  105.47
# 2     0  1/25/2000    287.15     0.135  1368.0  167.2400  102.410  106.04
# 3     0   2/1/2000    282.75     0.191  1311.0  166.8500  104.920  107.85
# 4     1   2/8/2000    298.40     0.312  1277.0  165.4300  104.220  109.30
# ...  ..        ...       ...       ...     ...       ...      ...     ...
# 1106  0  3/23/2021   1727.96     0.339  2271.0  184.5022   92.336  108.72
# 1107  0  3/30/2021   1685.56     0.303  2103.0  184.8741   93.297  110.29
# 1108  0   4/6/2021   1743.28     0.440  2092.0  185.8393   92.335  109.88
# 1109  0  4/13/2021   1742.69     0.467  2140.0  188.1368   91.852  109.19
# 1110  0  4/20/2021   1779.72     0.492  2432.0  193.8035   91.147  108.09
#
#          GBP    Cl1  ...  LP01TREU  EMUSTRUU  LF94TRUU     MXUS    MXEU  \
# ...

# %%
df.describe()
# Out:
#                  Y     XAU BGNL     ECSURPUS          BDIY          CRY  \
# count  1111.000000  1111.000000  1111.000000   1111.000000  1111.000000
# mean      0.213321   987.463744     0.036153   2259.860486   245.247670
# std       0.409837   494.623740     0.349453   2017.811888    68.278066
# min       0.000000   256.680000    -0.974000    291.000000   106.293000
# 25%       0.000000   433.740000    -0.191000    990.000000   184.705550
# 50%       0.000000  1137.800000     0.035000   1518.000000   234.560000
# 75%       0.000000  1324.825000     0.260500   2685.500000   301.539500
# max       1.000000  2006.910000     0.991000  11793.000000   467.570000
#
#                DXY          JPY          GBP          Cl1          VIX  ...  \
# count  1111.000000  1111.000000  1111.000000  1111.000000  1111.000000  ...
# mean     90.934982   106.605734     1.569661    60.708101    19.992169  ...
# std      11.379095    12.840754     0.212344    25.900813     8.642157  ...
# ...

# %%
sns.set_style(style="whitegrid")
plt.figure(figsize=(12,10))

# %%
sns.countplot(x="Y",data=df)
plt.title("Distribtution of Anormalies")
# Out:
# Text(0.5, 1.0, 'Distribtution of Anormalies')

# %%
df['Data'] = pd.to_datetime(df['Data'])
df = df.sort_values('Data')
sns.scatterplot(data=df, x="Data", y="VIX", hue="Y")
plt.title("VIX Anormalies")
# Out:
# Text(0.5, 1.0, 'VIX Anormalies')

# %%
import pandas as pd
import plotly.graph_objects as go

black_swan_events = [
    {"date": "2000-03-10", "label": "Dotcom Crisis"},
    {"date": "2001-09-11", "label": "9/11"},
    {"date": "2008-09-01", "label": "Financial Crisis"},
    {"date": "2009-11-05", "label": "EU Debt Crisis"},
    {"date": "2011-03-11", "label": "Fukushima Disaster"},
    {"date": "2014-01-01", "label": "Crude Oil Crisis"},
    {"date": "2015-08-24", "label": "China Black Monday"},
    {"date": "2020-03-03", "label": "COVID Pandemic"},
]
# Filter the data where Y == 1
y_equals_1_data = df[df['Y'] == 1]

#'BDIY','VIX',  'LF98TRUU','DXY', 'MXUS'
# Define the columns to plot
columns_to_plot = ['ECSURPUS', 'USGG30YR', 'XAU BGNL', 'Cl1', 'GTDEM10Y', 'USGG2YR', 'MXUS']

# Create a Plotly figure
fig = go.Figure()

# Add line plots for each column
for col in columns_to_plot:
    if col in df.columns:
        fig.add_trace(go.Scatter(
            x=df['Data'],
            y=df[col],
            mode='lines',
            name=f'{col} Stock Price',
            hovertemplate='<b>Date</b>: %{x}<br><b>Price</b>: %{y}<extra></extra>'
        ))

# Add scatter plots for anomalies (Y == 1)
for col in columns_to_plot:
    if col in y_equals_1_data.columns:
        fig.add_trace(go.Scatter(
            x=y_equals_1_data['Data'],
            y=y_equals_1_data[col],
            mode='markers',
            name=f'{col} Anomalies (Y=1)',
            marker=dict(color='blue', size=8),
            hovertemplate='<b>Date</b>: %{x}<br><b>Price</b>: %{y}<extra></extra>'
        ))

# Add vertical lines and annotations for black swan events
for event in black_swan_events:
    event_date = pd.to_datetime(event['date'])
    fig.add_shape(
        type="line",
        x0=event_date,
        x1=event_date,
        y0=df[columns_to_plot].min().min(),  # Minimum Y value
        y1=df[columns_to_plot].max().max(),  # Maximum Y value
        line=dict(color="red", width=2, dash="dash"),
    )
    fig.add_annotation(
        x=event_date,
        y=df[columns_to_plot].max().max(),
        text=event['label'],
        showarrow=False,
        yshift=10,
        font=dict(color="red", size=10),
    )

# Customize the layout
fig.update_layout(
    title="Stock Prices with Anomalies Highlighted (Y = 1)",
    xaxis_title="Date",
    yaxis_title="Stock Price",
    legend_title="Legend",
    template="plotly_white",
    xaxis=dict(showgrid=True),
    yaxis=dict(showgrid=True),
    hovermode="x unified"
)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import plotly.graph_objects as go
# List of black swan event dates and descriptions
black_swan_events = [
    #{"date": "2000-03-10", "label": "Dotcom Crisis"},
    #{"date": "2001-09-11", "label": "9/11"},
    #{"date": "2008-09-01", "label": "Financial Crisis"},
    #{"date": "2009-11-05", "label": "EU Debt Crisis"},
    # {"date": "2011-03-11", "label": "Fukushima Disaster"},
    # {"date": "2014-01-01", "label": "Crude Oil Crisis"},
    # {"date": "2015-08-24", "label": "China Black Monday"},
     {"date": "2020-03-03", "label": "COVID Pandemic"},
]

df['Data'] = pd.to_datetime(df['Data'])

# Define the date range for filtering
start_date = "2019-12-01"
end_date = "2021-12-31"

# Filter the DataFrame for the date range
filtered_df = df[(df['Data'] >= start_date) & (df['Data'] <= end_date)]

# Filter the data where Y == 1
y_equals_1_data = filtered_df[filtered_df['Y'] == 1]
#'ECSURPUS', 'USGG30YR',  'GTDEM10Y', 'USGG2YR'
#'BDIY','VIX',  'LF98TRUU','DXY', 'MXUS', 'XAU BGNL', 'Cl1',
# Define the columns to plot
columns_to_plot = [ 'EONIA','GTITL10YR', 'GTJPY10YR', 'MXUS' ]

# Create a Plotly figure
fig = go.Figure()

# Add line plots for each column
for col in columns_to_plot:
    if col in df.columns:
        fig.add_trace(go.Scatter(
            x=filtered_df['Data'],
            y=filtered_df[col],
            mode='lines',
            name=f'{col} Stock Price',
            hovertemplate='<b>Date</b>: %{x}<br><b>Price</b>: %{y}<extra></extra>'
        ))

# Add scatter plots for anomalies (Y == 1)
for col in columns_to_plot:
    if col in y_equals_1_data.columns:
        fig.add_trace(go.Scatter(
            x=y_equals_1_data['Data'],
            y=y_equals_1_data[col],
            mode='markers',
            name=f'{col} Anomalies (Y=1)',
            marker=dict(color='blue', size=8),
            hovertemplate='<b>Date</b>: %{x}<br><b>Price</b>: %{y}<extra></extra>'
        ))

# Add vertical lines and annotations for black swan events
for event in black_swan_events:
    event_date = pd.to_datetime(event['date'])
    fig.add_shape(
        type="line",
        x0=event_date,
        x1=event_date,
        y0=filtered_df[columns_to_plot].min().min(),  # Minimum Y value
        y1=filtered_df[columns_to_plot].max().max(),  # Maximum Y value
        line=dict(color="red", width=2, dash="dash"),
    )
    fig.add_annotation(
        x=event_date,
        y=filtered_df[columns_to_plot].max().max(),
        text=event['label'],
        showarrow=False,
        yshift=10,
        font=dict(color="red", size=10),
    )


# Customize the layout
fig.update_layout(
    title="Stock Prices with Anomalies Highlighted (Y = 1)",
    xaxis_title="Date",
    yaxis_title="Stock Price",
    legend_title="Legend",
    template="plotly_white",
    xaxis=dict(showgrid=True),
    yaxis=dict(showgrid=True),
    hovermode="x unified"
)



# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df['VIX_4Week_MA'] = df['VIX'].rolling(window=4).mean()
df['DXY_4Week_MA'] = df['DXY'].rolling(window=4).mean()
df['Cl1_4Week_MA'] = df['Cl1'].rolling(window=4).mean()
df['GTITL10YR_4Week_MA'] = df['GTITL10YR'].rolling(window=4).mean()
df['XAU_BGNL_4Week_MA'] = df['XAU BGNL'].rolling(window=4).mean()
df['LF98TRUU_4Week_MA'] = df['LF98TRUU'].rolling(window=4).mean()

# %%
features = df.drop('Y', axis=1)

# %%
# Specify the columns to include in the features
selected_columns = ['Data', 'VIX', 'BDIY']  # Replace with your column names

# Create features using only the selected columns
features = df[selected_columns]

features = features.dropna()

# %%
#features

# %%
target=df['Y']
#target

# %%
# Convert 'Data' column to datetime explicitly
features['Data'] = pd.to_datetime(features['Data'])
features['Y'] = df['Y']

# Define train and test sets based on the 'Data' column
train_data = features[features['Data'] < '2010-01-01']
test_data = features[features['Data'] >= '2010-01-01']

# %%
# Define X (features) and y (target) for training and testing
X_train = train_data.drop(['Data', 'Y'], axis=1)  # Exclude 'Data' and 'Y' from features
y_train = train_data['Y']
X_test = test_data.drop(['Data', 'Y'], axis=1)  # Exclude 'Data' and 'Y' from features
y_test = test_data['Y']

# # Verify the splits
# print(f"Training data size: {X_train.shape[0]} samples")
# print(f"Testing data size: {X_test.shape[0]} samples")

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X_train, y_train)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
scalar = StandardScaler()

X_train = scalar.fit_transform(X_train)
X_test = scalar.fit_transform(X_test)

# %%
from sklearn.ensemble import IsolationForest
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# Initialize the Isolation Forest model
iso_forest = IsolationForest(n_estimators=100, random_state=42, contamination=0.1)

# Train the model (fit on the features)
iso_forest.fit(X_resampled)

# Predict anomalies on the test set
# Anomalies are labeled as -1, and inliers as 1 in Isolation Forest
y_pred = iso_forest.predict(X_test)

# Convert predictions to binary format for comparison with true labels
# Assuming Y=1 is an anomaly in the original dataset
y_pred_binary = [1 if pred == -1 else 0 for pred in y_pred]

# Evaluate the model
print("Classification Report:")
print(classification_report(y_test, y_pred_binary))

print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred_binary))

# Additional evaluation
accuracy = accuracy_score(y_test, y_pred_binary)
print(f"\nAccuracy: {accuracy:.2f}")
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.76      0.80       484
#            1       0.23      0.32      0.27       106
#
#     accuracy                           0.68       590
#    macro avg       0.53      0.54      0.53       590
# weighted avg       0.73      0.68      0.70       590
#
#
# Confusion Matrix:
# [[369 115]
#  [ 72  34]]
#
# Accuracy: 0.68

# %%
from sklearn.ensemble import IsolationForest
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# Initialize the Isolation Forest model
iso_forest = IsolationForest(n_estimators=100, random_state=42, contamination=0.1)

# Train the model (fit on the features)
iso_forest.fit(X_train)

# Predict anomalies on the test set
# Anomalies are labeled as -1, and inliers as 1 in Isolation Forest
y_pred = iso_forest.predict(X_test)

# Convert predictions to binary format for comparison with true labels
# Assuming Y=1 is an anomaly in the original dataset
y_pred_binary = [1 if pred == -1 else 0 for pred in y_pred]

# Evaluate the model
print("Classification Report:")
print(classification_report(y_test, y_pred_binary))

print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred_binary))

# Additional evaluation
accuracy = accuracy_score(y_test, y_pred_binary)
print(f"\nAccuracy: {accuracy:.2f}")
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.83      0.84       484
#            1       0.27      0.29      0.28       106
#
#     accuracy                           0.73       590
#    macro avg       0.56      0.56      0.56       590
# weighted avg       0.74      0.73      0.74       590
#
#
# Confusion Matrix:
# [[402  82]
#  [ 75  31]]
#
# Accuracy: 0.73

# %%
# Required imports
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.metrics import classification_report, confusion_matrix
from imblearn.over_sampling import SMOTE
from xgboost import XGBClassifier

# Specify the columns to include in the features
selected_columns = ['Data', 'Y',
                    'DXY_4Week_MA', 'VIX_4Week_MA', 'Cl1_4Week_MA']  # Replace with your column names

# Create features using only the selected columns
features = df[selected_columns]

# Drop rows with missing values
features = features.dropna()

# Convert 'Data' column to datetime explicitly
features['Data'] = pd.to_datetime(features['Data'])

# Define train and test sets based on the 'Data' column
train_data = features[features['Data'] < '2015-01-01']
test_data = features[features['Data'] >= '2015-01-01']

# Ensure there are no missing values in train/test sets
train_data = train_data.dropna()
test_data = test_data.dropna()

# Define X (features) and y (target) for training and testing
X_train = train_data.drop(['Data', 'Y'], axis=1)  # Exclude 'Data' and 'Y'
y_train = train_data['Y']
X_test = test_data.drop(['Data', 'Y'], axis=1)  # Exclude 'Data' and 'Y'
y_test = test_data['Y']

# Apply SMOTE for oversampling to handle class imbalance
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X_train, y_train)

# Scale the features
scaler = StandardScaler()
X_resampled_scaled = scaler.fit_transform(X_resampled)
X_test_scaled = scaler.transform(X_test)

# Apply PCA to reduce the number of components to 4
pca = PCA(n_components=1)
X_resampled_pca = pca.fit_transform(X_resampled_scaled)
X_test_pca = pca.transform(X_test_scaled)

# Train and evaluate the XGBoost model
xgb_model = XGBClassifier(random_state=42, learning_rate=0.1, max_depth=5, n_estimators=100)
xgb_model.fit(X_resampled_pca, y_resampled)

# Predict on the test set
y_pred = xgb_model.predict(X_test_pca)

# Evaluate the model
print("Classification Report:")
print(classification_report(y_test, y_pred))
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94       290
#            1       0.00      0.00      0.00        39
#
#     accuracy                           0.88       329
#    macro avg       0.44      0.50      0.47       329
# weighted avg       0.78      0.88      0.83       329
#
#
# Confusion Matrix:
# [[290   0]
#  [ 39   0]]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import pickle

import xgboost as xgb
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier

# %%
lr_model = LogisticRegression(random_state=42)
lr_model.fit(X_train,y_train)
lr_predictions =lr_model.predict(X_test)
lr_accuracy = accuracy_score(y_test,lr_predictions)
print(f"Logistic Regression Accuracy: {lr_accuracy}")
print("Classification Report:")
print(classification_report(y_test, y_pred))
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Logistic Regression Accuracy: 0.8996960486322189
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94       290
#            1       0.00      0.00      0.00        39
#
#     accuracy                           0.88       329
#    macro avg       0.44      0.50      0.47       329
# weighted avg       0.78      0.88      0.83       329
#
#
# Confusion Matrix:
# [[290   0]
#  [ 39   0]]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# ...

# %%
def evaluate_and_save_model(model, X_train, X_test, y_train, y_test, filename):
  model.fit(X_train, y_train)
  y_pred= model.predict(X_test)
  accuracy = accuracy_score(y_test,y_pred)
  print(f"{model.__class__.__name__} Accuracy: {accuracy:.4f}")
  print(f"\nClassification Report: \n{classification_report(y_test,y_pred)}")
  print("------------")

  with open(filename, 'wb') as file:
    pickle.dump(model,file)

  print(f"Model saved as {filename}")

# %%
# Logistic Regression
lr_model = LogisticRegression(random_state=42)
evaluate_and_save_model(lr_model, X_resampled_pca, X_test_pca, y_resampled, y_test, "lr_model.pkl")

# XGBoost
xgb_model = xgb.XGBClassifier(random_state=42, learning_rate=0.7, max_depth=10, min_split_loss=3)
evaluate_and_save_model(xgb_model, X_resampled_pca, X_test_pca, y_resampled, y_test, "xgb_model.pkl")

# Decision Tree
dt_model = DecisionTreeClassifier(random_state=42)
evaluate_and_save_model(dt_model, X_resampled_pca, X_test_pca, y_resampled, y_test, "dt_model_moving average.pkl")

# Random Forest
rf_model = RandomForestClassifier(random_state=42)
evaluate_and_save_model(rf_model, X_resampled_pca, X_test_pca, y_resampled, y_test, "rf_model.pkl")

# Naive Bayes
mb_model = GaussianNB()
evaluate_and_save_model(mb_model, X_resampled_pca, X_test_pca, y_resampled, y_test, "mb_model.pkl")

# K-Nearest Neighbors
knn_model = KNeighborsClassifier()
evaluate_and_save_model(knn_model, X_resampled_pca, X_test_pca, y_resampled, y_test, "knn_model.pkl")

# Support Vector Machine
svm_model = SVC(random_state=42)
evaluate_and_save_model(svm_model, X_resampled_pca, X_test_pca, y_resampled, y_test, "svm_model.pkl")
# Out:
# LogisticRegression Accuracy: 0.8815
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94       290
#            1       0.00      0.00      0.00        39
#
#     accuracy                           0.88       329
#    macro avg       0.44      0.50      0.47       329
# weighted avg       0.78      0.88      0.83       329
#
# ------------
# Model saved as lr_model.pkl
# XGBClassifier Accuracy: 0.8815
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94       290
#            1       0.00      0.00      0.00        39
#
#     accuracy                           0.88       329
#    macro avg       0.44      0.50      0.47       329
# weighted avg       0.78      0.88      0.83       329
#
# ------------
# Model saved as xgb_model.pkl
# DecisionTreeClassifier Accuracy: 0.8723
#
# Classification Report:
# ...

# %%
xgb_model = xgb.XGBClassifier(random_state=42, learning_rate=0.7, min_split_loss=3, max_depth=10)
evaluate_and_save_model(xgb_model, X_resampled, X_test, y_resampled, y_test, "xgb_model_MA.pkl")

dt_model = DecisionTreeClassifier(random_state=42)
evaluate_and_save_model(dt_model, X_resampled, X_test, y_resampled, y_test, "dt_model.pkl")

rf_model = RandomForestClassifier(random_state=42)
evaluate_and_save_model(rf_model, X_resampled, X_test, y_resampled, y_test, "rf_model.pkl")

mb_model = GaussianNB()
evaluate_and_save_model(mb_model, X_resampled, X_test, y_resampled, y_test, "mb_model.pkl")

knn_model = KNeighborsClassifier()
evaluate_and_save_model(knn_model, X_resampled, X_test, y_resampled, y_test, "knn_model.pkl")

svm_model = SVC(random_state=42)
evaluate_and_save_model(svm_model, X_resampled, X_test, y_resampled, y_test, "svm_model.pkl")
# Out:
# XGBClassifier Accuracy: 0.9058
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95       290
#            1       0.90      0.23      0.37        39
#
#     accuracy                           0.91       329
#    macro avg       0.90      0.61      0.66       329
# weighted avg       0.91      0.91      0.88       329
#
# ------------
# Model saved as xgb_model_MA.pkl
# DecisionTreeClassifier Accuracy: 0.9027
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95       290
#            1       0.73      0.28      0.41        39
#
#     accuracy                           0.90       329
#    macro avg       0.82      0.63      0.68       329
# weighted avg       0.89      0.90      0.88       329
#
# ------------
# Model saved as dt_model.pkl
# RandomForestClassifier Accuracy: 0.8723
#
# Classification Report:
# ...

# %%
print(f"Shape of X_resampled: {X_resampled.shape}")
print(f"Shape of X_test: {X_test.shape}")
# Out:
# Shape of X_resampled: (774, 9)
# Shape of X_test: (590, 4)

# %%
from sklearn.ensemble import (
    RandomForestClassifier,
    GradientBoostingClassifier,
    StackingClassifier
)
# Gradient Boosting Classifier
gb_model = GradientBoostingClassifier(random_state=42, learning_rate=0.1, n_estimators=500)
evaluate_and_save_model(gb_model, X_train, X_test, y_train, y_test, "gb_model.pkl")

stacking_model = StackingClassifier(
    estimators=[
        ('rf', RandomForestClassifier(random_state=42)),
        ('knn', KNeighborsClassifier()),
        ('svm', SVC(random_state=42))
    ],
    final_estimator=LogisticRegression()
)
evaluate_and_save_model(stacking_model, X_train, X_test, y_train, y_test, "stacking_model.pkl")
# Out:
# GradientBoostingClassifier Accuracy: 0.8875
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94       290
#            1       0.58      0.18      0.27        39
#
#     accuracy                           0.89       329
#    macro avg       0.74      0.58      0.61       329
# weighted avg       0.86      0.89      0.86       329
#
# ------------
# Model saved as gb_model.pkl
# StackingClassifier Accuracy: 0.8997
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95       290
#            1       1.00      0.15      0.27        39
#
#     accuracy                           0.90       329
#    macro avg       0.95      0.58      0.61       329
# weighted avg       0.91      0.90      0.87       329
#
# ------------
# Model saved as stacking_model.pkl

# %%
xgb_model.fit(X_train, y_train)
feature_importance = xgb_model.feature_importances_
feature_names = features.columns.drop(['Data', 'Y'])
feature_importance
# Out:
# array([0.        , 0.0480239 , 0.        , 0.0335131 , 0.01851691,
#        0.01655293, 0.02111088, 0.01142594, 0.11366798, 0.01819772,
#        0.01072186, 0.        , 0.        , 0.        , 0.01428457,
#        0.01422318, 0.01720342, 0.        , 0.01424352, 0.24085769,
#        0.03105974, 0.        , 0.        , 0.        , 0.01365285,
#        0.01154812, 0.        , 0.        , 0.        , 0.        ,
#        0.14134747, 0.04261486, 0.        , 0.        , 0.02085461,
#        0.        , 0.01228716, 0.01243624, 0.        , 0.01078969,
#        0.        , 0.        , 0.0392662 , 0.        , 0.04515302,
#        0.01291204, 0.        , 0.01353438], dtype=float32)

# %%
feature_names
# Out:
# Index(['XAU BGNL', 'ECSURPUS', 'BDIY', 'CRY', 'DXY', 'JPY', 'GBP', 'Cl1',
#        'VIX', 'USGG30YR', 'GT10', 'USGG2YR', 'USGG3M', 'US0001M', 'GTDEM30Y',
#        'GTDEM10Y', 'GTDEM2Y', 'EONIA', 'GTITL30YR', 'GTITL10YR', 'GTITL2YR',
#        'GTJPY30YR', 'GTJPY10YR', 'GTJPY2YR', 'GTGBP30Y', 'GTGBP20Y', 'GTGBP2Y',
#        'LUMSTRUU', 'LMBITR', 'LUACTRUU', 'LF98TRUU', 'LG30TRUU', 'LP01TREU',
#        'EMUSTRUU', 'LF94TRUU', 'MXUS', 'MXEU', 'MXJP', 'MXBR', 'MXRU', 'MXIN',
#        'MXCN', 'VIX_4Week_MA', 'XAU_BGNL_4Week_MA', 'BDIY_4Week_MA',
#        'DXY_4Week_MA', 'Cl1_4Week_MA', 'GTITL10YR_4Week_MA'],
#       dtype='object')

# %%
feature_importances_df= pd.DataFrame({'Feature': feature_names, 'Importance': feature_importance})

# %%
feature_importances_df.sort_values(by='Importance', ascending=False)
# Out:
#                Feature  Importance
# 19           GTITL10YR    0.240858
# 30            LF98TRUU    0.141347
# 8                  VIX    0.113668
# 1             ECSURPUS    0.048024
# 44       BDIY_4Week_MA    0.045153
# 31            LG30TRUU    0.042615
# 42        VIX_4Week_MA    0.039266
# 3                  CRY    0.033513
# 20            GTITL2YR    0.031060
# 6                  GBP    0.021111
# 34            LF94TRUU    0.020855
# 4                  DXY    0.018517
# 9             USGG30YR    0.018198
# 16             GTDEM2Y    0.017203
# 5                  JPY    0.016553
# 14            GTDEM30Y    0.014285
# 18           GTITL30YR    0.014244
# 15            GTDEM10Y    0.014223
# 24            GTGBP30Y    0.013653
# 47  GTITL10YR_4Week_MA    0.013534
# 45        DXY_4Week_MA    0.012912
# 37                MXJP    0.012436
# 36                MXEU    0.012287
# 25            GTGBP20Y    0.011548
# 7                  Cl1    0.011426
# 39                MXRU    0.010790
# ...

# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

selected_columns = ['BDIY','VIX','XAU BGNL', 'Cl1', 'MXJP' ,'DXY', 'ECSURPUS', 'USGG30YR',  'GTDEM10Y', 'USGG2YR' ]
data = df[selected_columns]

# Step 2: Standardize the data
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data)

# Step 3: Apply PCA with 10 components
pca = PCA(n_components=10)  # Number of components set to 10
principal_components = pca.fit_transform(data_scaled)

# Step 4: Create a new DataFrame with principal components
pca_columns = [f'PC{i+1}' for i in range(10)]  # Naming principal components
pca_df = pd.DataFrame(data=principal_components, columns=pca_columns)

# Optional: Combine with target column for visualization or further use
if 'target' in df.columns:
    pca_df['target'] = df['target']

# Step 5: Visualize explained variance
plt.figure(figsize=(10, 6))
plt.bar(range(1, 11), pca.explained_variance_ratio_, alpha=0.7, color='b')
plt.xlabel('Principal Component')
plt.ylabel('Explained Variance Ratio')
plt.title('Explained Variance by Principal Components (10 Components)')
plt.show()

# Step 6: Cumulative Explained Variance
cumulative_variance = pca.explained_variance_ratio_.cumsum()
plt.figure(figsize=(10, 6))
plt.plot(range(1, 11), cumulative_variance, marker='o', linestyle='--', color='r')
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Cumulative Explained Variance (10 Components)')
plt.grid()
plt.show()

# %%
pca = PCA()
pca.fit(data_scaled)
cumulative_variance = pca.explained_variance_ratio_.cumsum()

plt.figure(figsize=(8, 6))
plt.plot(range(1, len(cumulative_variance) + 1), cumulative_variance, marker='o')
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Choosing Optimal Number of Components')
plt.show()
